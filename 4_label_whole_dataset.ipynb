# %%
import pandas as pd
import numpy as np
from transformers import CamembertTokenizer, CamembertForSequenceClassification
import torch
from torch.utils.data import TensorDataset, SequentialSampler, DataLoader

# Load the entire dataset
df_entire = pd.read_pickle("data/df_clean.pkl")

# Load the labeled sample data
df_labeled = pd.read_pickle("data/manually_labelled_df.pkl")

# %%
print(len(df_entire))
len(df_labeled)
# Out:
# 401987
# 4019

# %%
len(df_entire.author_id.unique())
# Out:
# 38836

# %%
# Specify the columns to check for duplicates
columns_to_check = ['author_id', 'created_at', 'retweet_count', 'reply_count', 'like_count', 'quote_count', 'lang', 'tweet']

# Remove duplicate rows based on the specified columns
df_entire.drop_duplicates(subset=columns_to_check, keep='first', inplace=True)
len(df_entire)
# Out:
# 401067

# %%
401067 - 4019
# Out:
# 397048

# %%
# Remove the labeled sample data from the entire dataset
df_labeled.drop(["_merge", "day", "week", "labels"], axis=1, inplace=True)

# Specify the columns to compare
columns_to_compare = ['author_id', 'created_at', 'retweet_count', 'reply_count', 'like_count', 'quote_count', 'lang', 'tweet', 'tweet_clean0']

# Perform a left merge to find rows in df_entire that are not in df_labeled
df_remaining = pd.merge(df_entire, df_labeled, on=columns_to_compare, how='left', indicator=True)

# Keep only rows that are not present in df_labeled
df_remaining = df_remaining[df_remaining['_merge'] == 'left_only']

# Drop the '_merge' column if not needed
df_remaining = df_remaining.drop(columns=['_merge'])

# %%
len(df_remaining)
# Out:
# 397048

# %%
# Load the previously saved model
model = CamembertForSequenceClassification.from_pretrained("models/camembert_model")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available():
    print("GPU is available.")
    print(f"Using device: {device}")
else:
    print("GPU is not available. Using CPU.")
# Out:
# GPU is available.
# Using device: cuda

# %%
batch_size = 16

# Initialize CamemBERT tokenizer
tokenizer = CamembertTokenizer.from_pretrained('camembert-base', do_lower_case=True)

# Create lists of texts and labels for the remaining data
text_remaining = df_remaining['tweet_clean0'].to_list()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
model_max_length = tokenizer.model_max_length
print(model_max_length)
# Out:
# 512

# %%
# Compute the maximum sequence length
max_length = 0
for sent in text_remaining:
    input_ids = tokenizer.encode(sent, add_special_tokens=True)
    max_length = max(max_length, len(input_ids))

# You can add a buffer value for padding if needed
MAX_LEN = max_length + 10

# Define a function for tokenizing and preprocessing data
def preprocess_data(texts):
    input_ids = []
    attention_masks = []

    for sent in texts:
        inputs = tokenizer.encode_plus(
            sent,
            add_special_tokens=True,
            max_length=MAX_LEN,  # Define MAX_LEN as appropriate
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt'
        )

        input_ids.append(inputs['input_ids'])
        attention_masks.append(inputs['attention_mask'])

    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)

    return input_ids, attention_masks

# %%
MAX_LEN
# Out:
# 151

# %%
# Print a message to indicate the start of tokenization and preprocessing
print("Tokenizing and preprocessing the remaining data...")

# Tokenize and preprocess the remaining data
inputs, masks = preprocess_data(text_remaining)

remaining_data = TensorDataset(inputs, masks)
remaining_sampler = SequentialSampler(remaining_data)
remaining_dataloader = DataLoader(remaining_data, sampler=remaining_sampler, batch_size=batch_size)
# Out:
# Tokenizing and preprocessing the remaining data...

# %%
len(inputs)
# Out:
# 397048

# %%
22276 * 16
# Out:
# 356416

# %%
# Validation of the model
model.to(device)  # Move the model to the device

# Set the model to evaluation mode to disable dropout layers, etc.
model.eval()

# Lists to store predicted labels for the entire remaining dataset
predictions_remaining = []

# Iterate over batches of data
for i, batch in enumerate(remaining_dataloader):
    batch = tuple(t.to(device) for t in batch)  # Move batch to the same device as the model
    input_ids, input_mask = batch

    with torch.no_grad():  # No need to compute gradients during inference
        outputs = model(input_ids, attention_mask=input_mask)
        logits = outputs.logits

    predictions_remaining.extend(logits.argmax(dim=1).cpu().numpy())  # Extend the predictions list

    # Check if the batch number is a multiple of 1000 before printing
    if (i + 1) % 1000 == 0:
        print(f"Processed batch {i+1}/{len(remaining_dataloader)}")

# Print a message to indicate the completion of model evaluation
print("Model evaluation completed.")
# Out:
# Processed batch 1000/24816
# Processed batch 2000/24816
# Processed batch 3000/24816
# Processed batch 4000/24816
# Processed batch 5000/24816
# Processed batch 6000/24816
# Processed batch 7000/24816
# Processed batch 8000/24816
# Processed batch 9000/24816
# Processed batch 10000/24816
# Processed batch 11000/24816
# Processed batch 12000/24816
# Processed batch 13000/24816
# Processed batch 14000/24816
# Processed batch 15000/24816
# Processed batch 16000/24816
# Processed batch 17000/24816
# Processed batch 18000/24816
# Processed batch 19000/24816
# Processed batch 20000/24816
# Processed batch 21000/24816
# Processed batch 22000/24816
# Processed batch 23000/24816
# Processed batch 24000/24816
# Model evaluation completed.

# %%
# Add these predictions to the manually labelled dataset
df_remaining['labels'] = predictions_remaining

df_labeled.rename(columns={"new_labels": "labels"}, inplace=True)

df_final = pd.concat([df_remaining, df_labeled], axis=0)

# Save the remaining dataset with predicted labels to a CSV file
df_final.to_csv("data/entire_dataset_labeled_final.csv", index=False)

# %%
len(df_final)
# Out:
# 401067

# %%
# Count the occurrences of 1s and 0s
counts = np.bincount(df_final["labels"])

# Calculate the percentage of 1s and 0s
total_count = len(df_final["labels"])
percentage_1 = (counts[1] / total_count) * 100
percentage_0 = (counts[0] / total_count) * 100

print(f"Percentage of 1s: {percentage_1:.2f}%")
print(f"Percentage of 0s: {percentage_0:.2f}%")
# Out:
# Percentage of 1s: 84.44%
# Percentage of 0s: 15.56%

# %%
sample = df_final.sample(100)

# %%
sample.reset_index(drop=True, inplace=True)
for i in range(100):
  print(sample["tweet_clean0"][i])
  print(sample["labels"][i])
  print("*******************")
# Out:
# Bonjour 👋Allez c'est repartie pour la semaine ,alors je vous souhaite de passer une bonne journée ,et bon courage aussi🤗🙏☀️😚😘#NonAuPassDeLaHonte #NonAuVaccinObligatoire #OnNeTouchePasAMesEnfants 🇫🇷✊🇫🇷💙🤍❤️
# 1
# *******************
# Le pédophile soixante-huitard #CohnBendit s’en prend aux parents qui refusent le vakxkxin à leurs enfants : « Le vakxkxin c’est formidable.les pauvres petits ils ne veulent pas être vakxkxinés ? Qu’ils aillent se faire foutre. »#Vaccin #vaccination #DictatureSanitaire
# 0
# *******************
# FLASH🇫🇷- Les parc aquatique pourront réouvrir des le 19 mai… mais sans eau . #COVID19 #NonAuPassSanitaire
# 1
# *******************
# Et la marmotte elle met le chocolat dans le papier !NonAuPassDeLaHonte#NonALaVaccinationObligatoire#DictatureSanitaire#FautArreterDeNousPrendrePourDesCons#ÇaSuffitLesConneries
# 1
# *******************
# J'espère que #Pfizer #AstraZeneca #Moderna vous remercieront #Macron20h #Macron #LR #Melenchon #Presidentielle2022 #LREM #ITA #CONCOURS #TDF2021 #TDF #Xbox #COVID19 #LCI #saccageparis #Veran #Fortnite #Passesanitaire #VaccinationObligatoire #antivax #F1 #racism
# 0
# *******************
# un vrai pervers narcissique qui devrait être en taule! #Resistance #soignants #VaccinationObligatoire #NonAuPassDeLaHonte #Manifs18septembre #justice #Macron #DictatureSanitaire
# 1
# *******************
# Il suffit de voir leurs leader pour être convaincu de la supériorité de l'intelligence des #antivax😂😂😂
# 0
# *******************
# Soirée réveillon annulée car ami(e)s covidés. Le plan B aurait été d'aller au restau avec mon fiston. Mais il est hors de question que je me soumette à ce pass de m. Ca se transforme en : bon repas bien arrosé et en plus on aura du bon SON ! 😋#StopDictatureSanitaire
# 1
# *******************
# 🔺Hormis deux trois égarés #antivax et #antitout … diffuse des vidéos de la capitale française 😂…tout le monde est la plage, seul reste celles et ceux qui ne veulent pas se protéger avec de la crème solaire 😎
# 0
# *******************
# Je crains très fort une ecatombe de cas positifs et de décès de ce virus extrêmement mortel le COVID19 chez nos "amis" les "forces de l'ordre" de la dictature Macron s'il sont exemptés du produit miracle qu'est le "vaccin".😜 #PassDeLaHonte#Manifs7aout#NonAuPassSanitaire
# 1
# *******************
# L'anorexie est évidente.Après, libre à vous d'utiliser ses soucis de santé pour alimenter votre combat #antivax.
# 0
# *******************
# #NonAuPassDeLaHonte Ils nous prennent pour des retardés. Sauf que c'est l'inverse 😂😎
# 1
# *******************
# et on va encore nous dire que nous ne sommes pas dans une dictature #NousSavons #NousSommesDesMillions #NousSommesLaResistance #GiletsJaunes
# 1
# *******************
# Les #AntiVax vont s'étouffer à m'avoir lu. 🙏
# 0
# *******************
# C'est physiquement impossible, les chiffres officiels de BFMTV font état de 114.123 personnes dans toutes la France.Compte signalé, merci de faciliter le travail de la police en respectant les distances de sécurité lors de votre interpellation.DictatureSanitaire
# 1
# *******************
# 🚨RT! Ça vs choque? Aujd en Australie,demain en France🤬! "Parce qu'on rêve tous de se retrouver,vaccinons-nous!"👏 #StopVaccinationObligatoire#StopPassSanitaire#StopDictatureSanitaire#StopFascismeSanitaire
# 1
# *******************
# Résumé de la situation avec les #antivax 🐒🐒🐒#ThinkingMonkey
# 0
# *******************
# Il aura été le président du #bullshit #StopDictatureSanitaire #MacronDemission
# 1
# *******************
# Encore une preuve que les #antivaxx sont des blaireaux.
# 0
# *******************
# 10 Millions contaminés,125000morts, 300 de ➕ /jour😡90 % #vaccination 🇫🇷Mais 95% d'#hospitalisation sont des #nonvaccinés ! Les #antivax nous EMMERDENT depuis 1an!Les #soignants 2 ans submergésJ'emmerde indignes de #presidentielles2022
# 0
# *******************
# Tableau général des différentes mesures sanitaires en Europe.Covid19 #StopDictatureSanitaire CARTE : l’Angleterre et l’Écosse confinent comme au printemps 2020 -
# 1
# *******************
# #StarsBulles #antivaccin : des coups d’éclat aux polémiques ⁦ "ses propos dits complotistes,franchi allègrement par Juliette Binoche il y a un an, quand elle relayait sur Instagram des théories pour le moins farfelues .
# 0
# *******************
# #PassSanitaire "ça a été une stratégie payante pour se faire vacciner" #Macron…🤔Sauf que le Conseil d’État estimait qu’il ne devait être qu’une «mesure pour limiter la propagation de l’épidémie», et non un dispositif visant à inciter à se faire vacciner‼️#NonAuPassDeLaHonte
# 1
# *******************
# #NonAuPassSanitaire Tous dans la rue demain!
# 1
# *******************
# Fake News ?La base de données "carte mondiale des incidents".Aucune incidence d'un pilote "delta" n’a été signalée au cours de cette période aux États-Unis. #VaccinezVous #antivax #faitesvousvacciner #COVID19 #PasseSanitaire
# 0
# *******************
# LIBERTÉ‼️ÉGALITÉ‼️RÉSISTANCE👏#NousSommesDesMillions #NousSavons 🛑🤥 🛑aux chantages 🛑aux menaces 🛑aux mesures coercitives sur NOTRE VIE PRIVÉE‼️🛑 au pass NAZITAIRE pour nous SOUMETTRE 🛑 au vaccin dangereux et inutile, puisque à refaire indéfiniment‼️😱🤮-RESTONS UNIS-✊👍
# 1
# *******************
# vous êtes notre fierté! #sallesdesport #piscines #jesuislibre #réveillezvous #COVID19 #StopDictatureSanitaire #Vaccin #raveparty
# 1
# *******************
# #Macron toujours à cracher sur les Français …. Nous somme dans une #DictatureSanitaire
# 1
# *******************
# Aujourd'hui 12 octobre : * de 16h à 16h21 : black-out : couper ses appareils électriques et son téléphone portable ; * à 17h rendez-vous devant le #Sénat à Paris pour un "standing" #NonALaVaccinationObligatoire #NonAuPassDeLaHonte
# 1
# *******************
# #NonAuPassVaccinal #ZAD #liberte #MacronDestitution #interetsprives #lobbying #contratsocial #liberteconditionnelle vous voulez continuer avec lui?
# 1
# *******************
# Nous allons résister #NonAuPassVaccinal #NonAuVaccinObligatoire
# 1
# *******************
# De quoi émettre de sérieux doutes sur la sincérité des chiffres communiqués ici 🇫🇷 #NonALaVaccinationObligatoire #Israel #NonAuPassDeLaHonte
# 1
# *******************
# .Nous vaincrons#NousSommesDesMillions #NouSavons
# 1
# *******************
# Au fond, #BigPharma gagne plus d’argent si vous ne vous faites pas vacciner. C’est aussi bon pour l’économie, vous faites vivre des entreprises funéraires et les commerces qui gravitent autour. Merci, les #antivax et les #NonVax
# 0
# *******************
# Y'a d'quoi l'être 🤦🏻‍♂️ #AntiToutes #antivaxx #CriseDuBacon
# 1
# *******************
# En "bonne démocratie" le gouvernement a donné aux chaînes TV la consigne d'occulter la manif #antivax ! Initiative contre productive !Toujours dans la dissimulation comme pour les ingrédients du ARNM #cnews #lci #BFMTV #franceinfo #PassSanitaireDeLaHonte
# 1
# *******************
# Oui oui, quelques personnes, c'est pourquoi de plus en plus de manifestations et de rassemblements contre la #DictatureSanitaire ont lieu. C'est toi la personne isolée, qui est incapable d'ouvrir ses putains d'yeux.
# 1
# *******************
# Vrai.Pourtant en 2012 les animateurs de Québec. et de l’establishment applaudissaient la police qui brutalisait sauvagement les étudiants et les manifestants pacifiques.Votre réveil à pris du temps. Mais bon ✌️#polqc #DictatureSanitaire #manifencours #ggi
# 1
# *******************
# "Un peuple prêt à sacrifier un peu de liberté pour un peu de sécurité ne mérite ni l’une ni l’autre, et finit par perdre les deux." Benjamin FranklinJe pense que cette citation est un peu d'actualités non ? #PassVacinal #Vaccin #StopHysterieSanitaire #StopDictatureSanitaire
# 1
# *******************
# #PassSanitaireDeLaHonte #NousSommesDesMillions #StopDictatureSanitaire #manif20novembre #Manifs20novembre #VaccinezVous #PassSanitaireC pas la 5e vague, c le revers de la médaille de leur piquouse de merde, comme en Israel, Irlande, Islande, Allemagne, Corée du sud, Australie.
# 1
# *******************
# #Resistance #NousSommesDesMillions #manif18septembre #PassDeLaHonte #TouchePasAmesGosses #NousSavons #liberte
# 1
# *******************
# c'est une logique spécifique à la dictature sanitaire dotée d'une milice armée pour nous rappeler notre statut d'esclaves! #piscines #jesuislibre #StopDictatureSanitaire #Desobeissancecivile #MacronDestitution #VaccinationCovid #confinement3 #Absurdistan
# 1
# *******************
# 🚩BREAKING : Mes cartes me disent qu'on va bientôt être débarrassés de et, dans la foulée, de sa copine D'une pierre deux coups ‼👍👍 #DictatureSanitaire #NarratifC19 #Nudge #Nuremberg2
# 1
# *******************
# Les chemises noires et le #fascisme #italien est de retour! #chemisesnoires#Covid19 #coronavirus #VaccinationObligatoire #EffetsSecondaires #PassDeLaHonte #ivermectine #refusdesoigner #Ivermectine #hydroxychloroquine #dictaturesanitaire#DictaduraSanitaria #Italie
# 1
# *******************
# ça c'est sure vu le nombre de vaccins disponibles et la com' anxiogène du gvt depuis des mois!"#restaurants #sallesdesport #piscines #jesuislibre #COVID19 #StopDictatureSanitaire
# 1
# *******************
# Une tragi-comédie sans fin.DictatureSanitaire #poison
# 1
# *******************
# Je ne suis pas un numéro😉#MarcheDesLibertés#66MillionsDeProcureurs#TousComplotistes#GiletsJaunes#ViolencesPolicières#DictatureSanitaire#DarmaninDémission#COVID19#MacronDestitution#JeNeMeConfineraiPas
# 1
# *******************
# #manif31juillet #TousEnsemble #TousAntiPass #martinique #Guadeloupe #TousUnis #manifs31juillet #NousSavons #noussommesdesmillions#NonAuPasseDeLaHonte #NonAuPassSanitaire #non au #passesanitaire #PassSanitaires #manifestation31juillet
# 1
# *******************
# J'ai violé la charte COVID, 12h de suspensionLes #antivaxx et #antitout Tweetent et RT #fakenews et #fauxtémoignages. Horreurs #complotistes 24/24 7/7.Et pour un argument retourné (avec humour) à ces cons je me fais censurer (dénoncer) ?NON à la #DictatureDesCons
# 0
# *******************
# Combien, du couloir de la mort "Soins Palliatifs" ont-ils fini dans un four ?DICTATURE #DictatureSanitaire #NaturalSelection #Eugenism #Shoah
# 1
# *******************
# Les #covidiots #antivax sont de plus en plus stupides et ne méritent pas qu’on perde du temps à tenter de les convaincre.Il n’y aura de tte manière pas de vaccin pour tout le monde dans les 6 prochains mois.
# 0
# *******************
# Incroyable ! 😲L’État aurait prévenu Doctolib en amont pour qu'ils puissent anticiper la forte hausse des RDV induite par ses annonces ? Quelle honte !Si il ne l'avait pas fait, vous les auriez traiter d'amateurs.antivaxx#guignols
# 0
# *******************
# Si j'ai bien compris, au vu des reportages des #telestoutinfo, pourtant prompts à montrer le verre à moitié vide, la part des #personnels de soins #antiVax qui risquent la suspension de leur emploi et de leur salaire est très modérée. C'est une bonne nouvelle.
# 0
# *******************
# La pendaison! Ce sera très certainement des fraudeurs, de faux vaccinés!🇨🇵#antivax #vichycestfini #manif31juillet
# 0
# *******************
# Le tweet a été supprimé par son auteur. Nous avons échangé sur le sujet. Merci à lui.Ce qui doit rester notre force, c'est d'être non manipulables par des soit disants "résistants", qui ne sont que des fils de bourgeois parisiens, surtout en ces temps de #dictaturesanitaire !
# 1
# *******************
# faisons nous confiance .Cessons de monter les français les uns contre les autres . Ne cédons pas à la peur. La liberté guidant le peuple . non la peur .StopDictatureSanitaire
# 1
# *******************
# 👋🇫🇷PassS Marche🚶‍♀️Et tais-toi🤐Cé pas prêt 2se finir ce🎪 demander le programme pr ce week-end #StopDictatureSanitaire #JeNeMeVaccineraiPas #NouSavons #MacronDemission
# 1
# *******************
# Manif prévues jusqu'en Octobre !BraceletBleuCommeDesBoeufs #NonAuPassSanitaire
# 1
# *******************
# pas besoin de Zemmour pour être à Genoux #Macron et toute votre clique vous en êtes largement chargé !NonAuPassDeLaHonte #manif4septembre
# 1
# *******************
# #NousSommesDesMillions
# 1
# *******************
# Excellent cet appel à la #GreveGenerale pour ma part je pense aussi qu'une reprise de #NuitDebout serait aussi d'actualité mais bon il faut tenir dans le froid bien évidemment#NonALaVaccinationObligatoire #NonAuPassVaccinal
# 1
# *******************
# #NonAuPassVaccinal pétition contre le pass vaccinal. À ce jour, presque 700 000 signatures. Diffuser sans modération 😇😇😇
# 1
# *******************
# 🇦🇺 #MelbourneprotestLes infirmières manifestent à #perth#NonALaVaccinationObligatoire #NonAuPassDeLaHonte
# 1
# *******************
# Lettre aux députés #LFI #StopDictatureSanitaire
# 1
# *******************
# Ivermectine est bien connu, depuis des années c'est plus sûr que ces vaccins dont on ne connaît rien sur le long terme #NonAuPassDeLaHonte #NonAuPassSanitaire
# 1
# *******************
# "Les vieux" pas sûr que c'était leur clientèle principale qui faisait "tourner leur boutique"!boycottons tous ces endroits! #NonAuPassDeLaHonte#NonAuPassSanitaire
# 1
# *******************
# #covid #Vaccin#GAMEOVER#ANTIVAXX Découvre la vidéo de yono34658 ! #TikTok
# 0
# *******************
# Un thread exceptionnel. Merci à de nous faire partager cet article à la conclusion époustouflante !StopDictatureSanitaire
# 1
# *******************
# Lyon #manifestation31juillet #NousSommesDesMillions #NonAuPasseDeLaHonte
# 1
# *******************
# 🔥 LA RESTAURATION A PAYÉ LE PRIX FORT de la politique liberticide du d'Le chiffre d'affaires en chute libre de 45% et la fréquentation de 39%⤵️⤵️⤵️#LaFranceLibre#AntiPassSanitaire#NonAuPassDeLaHonte
# 1
# *******************
# Scandaleux ! #DictatureSanitaire #DictatureEnMarche laissez ces gamins tranquilles. ! #Desobeissancecivile
# 1
# *******************
# A ne pas être vaccinés, sissi,👉#NousSommesDesMillions 😏
# 1
# *******************
# Macron qui démissionne avant le mois de mai, mais ça n’a aucun sens. Surtout que Macron prépare sa réélection.Le problème avec les #antivax et les #antipass, c’est qu’ils baignent dans une bulle complotiste hors-sol.
# 0
# *******************
# 💥👏👏👏👍 #StopConfinement3 ☠️💥 Nous ne les laisserons pas tuer la France et les Français ce #GVT de💩#DictatureSanitaire #ConfinementPréventif #MortsEhpadsGVT #Confinement3 #GénocideEnMarche123 #COVID19
# 1
# *******************
# Bienvenue !NonAuPassVaccinalVaccinés, ils refusent la dose de rappel : "Je n'ai plus confiance, ni en ce vaccin, ni en nos dirigeants" | Actu
# 1
# *******************
# Quand l’état a surtout peur de la révolte populaire. Ont plus peur de perdre leurs privilèges que du virus en fait. On a plus de munitions LBD que de vaccins en vrai. Le vrai virus on le connaît ! #StopMacron #OnVeutLesNoms #StopDictatureSanitaire
# 1
# *******************
# La propagande coviétique s'infiltre jusque dans nos propres publications. #stopdictaturesanitaire
# 1
# *******************
# Ça commence à réfléchir, il est temps #NonALaVaccinationObligatoire #NonAuPassDeLaHonte #onnelacherien
# 1
# *******************
# Question inutile ⚠️ Les non-vaccinés ne se reconfinerons pas . Faut bien que le gouvernement comprenne qu'ils sont rentrés en #Resistance contre #Macron et sa #DictatureSanitaire
# 1
# *******************
# #WebJournal - Le #problème de nos #politiciens dans ce #monde se nomme l'#ego et le #roi de l'ego se nomme, #Macron, c'est à méditer. #Covid_19 #COVID19 #CoronaVirus #Grippe #Attestation #Masque #Vérité #DictatureChinoise #DictatureSanitaire #Dictature #Virus
# 1
# *******************
# Donnez votre avis sur la vaccination des enfants de 5-11 ans.RT le sondage pour faire passer le message à #Macron.ParceQueCestNotreProjet#NonALaVaccinationObligatoire #NonAuPassDeLaHonte #TouchezPasAuxEnfants #DictatureSanitaire #4emedose #3edose
# 1
# *******************
# Pfff l’évolution d’une épidémie contagieuse mais bénigne ne nous interesse pas sauf si on y inclut les morpions et les rhumes #NousSavons #NonAuPassDeLaHonte
# 1
# *******************
# Une société qui a la peur constante de la mort est une société déjà morte.Macron#UnionSacree#Omicron #passvaccinal #PassSanitaire #ggrmc #NonAuPassVaccinal
# 1
# *******************
# Donc d’après le journal il n’y a que 100 000 connards en #France …c’est plutôt rassurant je trouve 😊 #antivaxx #Antivaccin #antipass #FuckLesAntivaxx #VaccinObligatoire #VaccinationObligatoire
# 0
# *******************
# Chacun son tour ! Qu'il entre en #Resistance #NonAuPassDeLaHonte
# 1
# *******************
# Affligeant une fois de plus. " J'ai décidé " rien du tout puisque c'était déjà décidé. Sinon 5e vague, 6e vague ? #NonAuPassDeLaHonte
# 1
# *******************
# Tout le monde est couvert dans cette affaire.Sauf le "vacciné" - contribuable - assuré social.ScandalePfizer #DictatureSanitaire #PassSanitaire #Manifs18decembre #NonAuPassDeLaHonte #NonAuPassSanitaire #NonAuVaccinObligatoire#Covid_19#COVID19
# 1
# *******************
# Belfort. Condamné pour avoir brandi une pancarte avec des sigles nazis lors d’une manif anti-pass #antivaxx (et pour avoir essayé de voler des armes dans le coffre d’une voiture de policiers, avoir refusé la prise d’empreintes et donné un faux nom)
# 0
# *******************
# #NousSommesDesMillions a considérer que la #France est un pays Européen géographiquement, culturellement et historiquement. #NousSommesDesMillions a nous sentir plus proche de nos voisins Européens que de nos anciennes colonies.NousSommesDesMillions de vaccines.
# 1
# *******************
# Une idée pour échapper à la vaccination ?😅#COVID19 #StopDictatureSanitaire #passeportSanitaire
# 1
# *******************
# Il emmerde tout le monde, juste dans le but de mettre sous état d'urgence pour annuler les élections. Pas grave. #Covid_19 #surenchere #GreveGenerale #NousSommesDesMillions #NonAuPassVaccinal #democratie #1942nonmerci
# 1
# *******************
# Le compte d' va sauter d'ici peu, BFM💩 est sur l'affaire.DictatureSanitaire
# 1
# *******************
# Un #antivax dégonflé
# 0
# *******************
# Quels cheminots ? Vous connaissez le statut de ceux qui contrôlent les pass ? Enrichissez ! #NonAuPassDeLaHonte
# 1
# *******************
# Alerte ! Les #vaccinés sont #contaminants et contaminent tout le monde ! Inefficacité et extrême dangerosité des #vaccins. #NonALaVaccinationObligatoire #NonAuPassDeLaHonte
# 1
# *******************
# Un incendie d'un appartement dans le Bronx New York🇺🇸 a fait 19 morts un vrai enfer dans cet immeuble.Paix à leurs âmes#NonAuVaccinObligatoire #antivaxx
# 1
# *******************
# #NousSavons#Résistons !NousSommesDesMillions#NonAuPassDeLaHonte#NonDictatureNazitaire#14Juillet #14Juillet2021DansLaRue
# 1
# *******************
# #TSM Tous Sauf Macron 2022 / #NonAuPassDeLaHonte #VeranDemission #VeranEnPrison #PassSanitaire #3emeDose #GiletsJaunes
# 1
# *******************
# Les infirmières niçoises mobilisées comme jamais !NonAuPassDeLaHonte #NonALaVaccinationObligatoire
# 1
# *******************
# Le #PassSanitaire c'est le pass totalitaire. Qui défend de tels dispositifs discriminatoires défend la dictature. Au fait, où en est le #Pfizergate avec tout ça ? A quand le retour de la démocratie et du libre consentement ? #NonAuVaccinObligatoire #NonAuPassSanitaire
# 1
# *******************
